# %%
from data_process import *
from data_plot import *

# %%
y, x = svm_data_process('abalone.txt')
# Out:
# -1 1:0.0 2:0.485 3:0.39 4:0.1 5:0.5565 6:0.2215 7:0.1155 8:0.185
# -1 1:-1.0 2:0.46 3:0.36 4:0.125 5:0.547 6:0.2165 7:0.1105 8:0.19
# -1 1:-1.0 2:0.46 3:0.35 4:0.125 5:0.5165 6:0.1885 7:0.1145 8:0.185
# +1 1:-1.0 2:0.535 3:0.42 4:0.125 5:0.764 6:0.312 7:0.1505 8:0.265
# +1 1:-1.0 2:0.465 3:0.36 4:0.105 5:0.488 6:0.188 7:0.0845 8:0.19
# +1 1:-1.0 2:0.51 3:0.4 4:0.14 5:0.6905 6:0.259 7:0.151 8:0.23
# +1 1:1.0 2:0.335 3:0.26 4:0.09 5:0.1835 6:0.078 7:0.024 8:0.065
# +1 1:-1.0 2:0.55 3:0.425 4:0.16 5:0.97 6:0.2885 7:0.139 8:0.48
# -1 1:1.0 2:0.18 3:0.135 4:0.08 5:0.033 6:0.0145 7:0.007 8:0.01
# -1 1:1.0 2:0.215 3:0.165 4:0.055 5:0.059 6:0.0265 7:0.0125 8:0.0185
# -1 1:1.0 2:0.2 3:0.15 4:0.04 5:0.046 6:0.021 7:0.007 8:0.0065
# -1 1:0.0 2:0.625 3:0.48 4:0.2 5:1.3235 6:0.6075 7:0.3055 8:0.355
# +1 1:-1.0 2:0.55 3:0.42 4:0.17 5:0.8465 6:0.336 7:0.2405 8:0.245
# +1 1:-1.0 2:0.585 3:0.45 4:0.15 5:1.047 6:0.4315 7:0.276 8:0.315
# +1 1:0.0 2:0.645 3:0.5 4:0.18 5:1.2785 6:0.5345 7:0.2995 8:0.345
# ...

# %%
plot_data('../abalone_cross_error.txt')

# %%
plot_ten_fold('../abalone_cross_error_ten_fold.txt')
# Out:
# No handles with labels found to put in legend.

# %%
plot_sv('../abalone_cross_error_ten_fold.txt')
